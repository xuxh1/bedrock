# %%
from pathlib import Path

dir_path = Path("/share/home/dq076/bedrock/data/P/CHIRPS_v3_IMERGlate_v07/8D")

old_str = "ET_"
new_str = "P_"

for file in dir_path.glob("*.nc"):
    new_name = file.name.replace(old_str, new_str)
    file.rename(file.with_name(new_name))
