# %%
from pathlib import Path

dir_path = Path("/tera04/zhwei/xionghui/bedrock/data/run/veg_activity/tiles")

old_str = ".nc4"
new_str = ".nc"

for file in dir_path.glob("*"):
    new_name = file.name.replace(old_str, new_str)
    file.rename(file.with_name(new_name))
