# %% [markdown]
# # 1. Preprocess the MODIS GLASS downward shortwave radiation

# %% [markdown]
# ### 1.1 Download the data from https://www.glass.hku.hk/archive/DSR/MODIS/0.05D/

# %%
#!/usr/bin/env python3
from pathlib import Path
import subprocess

OUT_DIR = Path("/share/home/dq076/bedrock/data/DSR/GLASS/rawdata")
OUT_DIR.mkdir(parents=True, exist_ok=True)

for year in range(2003, 2021):
    url = f"https://www.glass.hku.hk/archive/DSR/MODIS/0.05D/{year}/"
    print(f"[YEAR] {year}")

    cmd = [
        "wget",
        "-r",                      # 递归
        "-np",                     # 不进入上级目录
        "-nH",                     # 不创建域名目录
        "--cut-dirs=5",            # 去掉 archive/DSR/MODIS/0.05D/{year}
        "-A", "*.hdf",             # 只下 hdf
        "-c",                      # 断点续传 
        "--tries=0",               # 无限重试
        "--retry-conDSRefused",
        "--waitretry=5",
        "--timeout=30",
        "-P", str(OUT_DIR),        # 输出目录
        url,
    ]

    subprocess.run(cmd, check=True)

# %% [markdown]
# ### 1.2 Translate the data from 1D hdf to 8D nc4

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
GLASS DSR daily HDF -> 8-day NC4 (zip_3) using GDAL + CDO
(HDF4Image/HDF4 Dataset style: no EOS_GRID subdatasets)

- Apply scale (0.01) using gdal_translate -unscale
- Convert to float32 directly in gdal_translate to preserve decimal precision
- Output in EPSG:4326 (already in geographic coordinates)
"""

import re
import sys
import shutil
import tempfile
import subprocess
from pathlib import Path
from datetime import datetime, timedelta

# -----------------------
# CONFIG
# -----------------------
IN_DIR  = Path("/share/home/dq076/bedrock/data/DSR/GLASS/rawdata").resolve()
OUT_DIR = Path("/share/home/dq076/bedrock/data/DSR/GLASS/8D").resolve()
OUT_DIR.mkdir(parents=True, exist_ok=True)

PRODUCT = "GLASS05B01"
VAR_OUT_NAME = "DSR"

START_DATE = datetime(2003, 1, 1)
END_DATE   = datetime(2020, 12, 31)
STEP_DAYS = 8

# GLASS metadata
NODATA_IN = "-1"
SCALE_FACTOR = 0.01  # GLASS scale_factor in metadata

# 输出数据类型：强制为Float32以保留小数精度
OUTPUT_DTYPE = "Float32"  # GDAL支持的类型：Byte, Int16, UInt16, Int32, UInt32, Float32, Float64

# 使用EPSG:4326（WGS84）作为输出坐标系（虽然数据基于Clarke 1866椭球，但相差很小）
TARGET_SRS = "EPSG:4326"

# Choose 8-day aggregation: "timmean" or "timsum"
AGG = "timmean"

PAT = re.compile(rf"^{re.escape(PRODUCT)}\.V\d+\.A(\d{{4}})(\d{{3}})\..*\.hdf$")


def run(cmd, cwd=None):
    p = subprocess.run(cmd, cwd=cwd, text=True, capture_output=True)
    if p.returncode != 0:
        raise RuntimeError(
            "Command failed:\n"
            f"  cmd: {' '.join(cmd)}\n"
            f"  cwd: {cwd}\n"
            f"  stdout:\n{p.stdout}\n"
            f"  stderr:\n{p.stderr}\n"
        )
    return p.stdout


def yyyyddd(dt: datetime) -> str:
    return dt.strftime("%Y") + f"{dt.timetuple().tm_yday:03d}"


def yyyymmdd(dt: datetime) -> str:
    return dt.strftime("%Y-%m-%d")


def find_hdf_for_date(dt: datetime) -> Path | None:
    key = yyyyddd(dt)
    candidates = sorted(IN_DIR.glob(f"{PRODUCT}.V*.A{key}.*.hdf"))
    return candidates[0] if candidates else None


def check_tools():
    for tool in ["gdal_translate", "gdalinfo", "cdo"]:
        if shutil.which(tool) is None:
            raise RuntimeError(f"Missing required tool in PATH: {tool}")
    run(["gdalinfo", "--format", "netCDF"])
    run(["cdo", "-V"])


def hdf_dataset_uri(hdf_path: Path) -> str:
    return str(hdf_path)


def export_daily_nc(dt: datetime, hdf_path: Path, out_nc: Path):
    """
    Export daily DSR to a 1-timestep netCDF file:
      - Apply scale_factor via gdal_translate -unscale
      - Convert to float32 directly to preserve decimal precision
      - Assign EPSG:4326 coordinate system
      - Add time axis via setdate/settime
    """
    with tempfile.TemporaryDirectory(prefix="glass_DSR_day_") as td:
        td = Path(td)
        raw_nc = td / "raw.nc4"
        
        # 关键修改：一步完成所有转换
        print(f"    Converting {hdf_path.name} to netCDF...")
        
        # 使用gdal_translate直接完成：
        # 1. -unscale: 应用scale_factor (×0.01)
        # 2. -ot Float32: 直接转换为浮点数，避免精度损失
        # 3. -a_srs EPSG:4326: 分配WGS84坐标系（虽然原始是Clarke 1866，但差异很小）
        # 4. -a_nodata: 设置无效值
        run([
            "gdal_translate",
            "-q",
            "-of", "netCDF",
            "-co", "FORMAT=NC4",
            "-ot", OUTPUT_DTYPE,      # 关键：直接输出为浮点数
            "-unscale",               # 应用scale_factor (0.01)
            "-a_nodata", NODATA_IN,
            "-a_srs", TARGET_SRS,     # 分配坐标系（不是重投影）
            hdf_dataset_uri(hdf_path),
            str(raw_nc)
        ])
        
        # 设置变量名和时间坐标
        # 注意：不再需要CDO的-b F32参数，因为gdal_translate已经输出浮点数
        run([
            "cdo", "-O", "-L",
            "-f", "nc4", "-z", "zip_3",
            f"-setname,{VAR_OUT_NAME}",
            f"-setdate,{yyyymmdd(dt)}",
            "-settime,00:00:00",
            str(raw_nc),
            str(out_nc)
        ])
        
        # 可选：验证输出数据类型
        # run(["ncdump", "-h", str(out_nc)])


def make_8day(daily_files: list[Path], out_nc: Path):
    """
    Merge 8 daily files and compute 8-day aggregation (mean or sum).
    """
    with tempfile.TemporaryDirectory(prefix="glass_DSR_8day_") as td:
        td = Path(td)
        merged = td / "merged.nc4"

        # 合并时间序列
        run([
            "cdo", "-O", "-L",
            "-f", "nc4", "-z", "zip_3",
            "mergetime", *map(str, daily_files), str(merged)
        ])

        # 计算8天聚合
        run([
            "cdo", "-O", "-L",
            "-f", "nc4", "-z", "zip_3",
            AGG, str(merged), str(out_nc)
        ])


def main():
    check_tools()

    dt = START_DATE
    n_done = n_skip = n_warn = 0

    print(f"IN_DIR : {IN_DIR}")
    print(f"OUT_DIR: {OUT_DIR}")
    print(f"Range  : {START_DATE.date()} -> {END_DATE.date()} (8-day non-overlap)")
    print(f"AGG    : {AGG}")
    print(f"Output dtype: {OUTPUT_DTYPE}")
    print(f"Target SRS: {TARGET_SRS}")
    print(f"Note: Data already in geographic coordinates, using -a_srs (not reprojection)")

    while dt <= END_DATE:
        key = yyyyddd(dt)
        out_nc = OUT_DIR / f"DSR_GLASS_{key}_8D_p05_Wm2.nc4"

        if out_nc.exists():
            print(f"[SKIP] A{key} exists")
            n_skip += 1
            dt += timedelta(days=STEP_DAYS)
            continue

        daily_dates = [dt + timedelta(days=i) for i in range(STEP_DAYS)]
        daily_hdfs = []
        missing = []

        for d in daily_dates:
            if d > END_DATE:
                break
            h = find_hdf_for_date(d)
            if h is None:
                missing.append(d)
            else:
                daily_hdfs.append(h)

        if len(daily_hdfs) != STEP_DAYS:
            print(f"[WARN] A{key}: missing {STEP_DAYS - len(daily_hdfs)} day(s): "
                  + ", ".join(yyyymmdd(x) for x in missing[:10])
                  + (" ..." if len(missing) > 10 else ""))
            n_warn += 1
            dt += timedelta(days=STEP_DAYS)
            continue

        print(f"[RUN ] A{key}: {yyyymmdd(dt)} .. {yyyymmdd(dt+timedelta(days=7))}")

        with tempfile.TemporaryDirectory(prefix=f"glass_DSR_A{key}_") as td:
            td = Path(td)
            daily_ncs = []
            for d, hdf in zip(daily_dates, daily_hdfs):
                day_nc = td / f"DSR_{yyyymmdd(d)}.nc4"
                export_daily_nc(d, hdf, day_nc)
                daily_ncs.append(day_nc)

            make_8day(daily_ncs, out_nc)

        print(f"[OK ] A{key} -> {out_nc.name}")
        n_done += 1
        dt += timedelta(days=STEP_DAYS)

    print("==== SUMMARY ====")
    print(f"done: {n_done}, skip: {n_skip}, warn(missing): {n_warn}")
    print(f"Output: {OUT_DIR}")


if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        print(f"[FATAL] {e}", file=sys.stderr)
        sys.exit(1)
# Out:
# IN_DIR : /share/home/dq076/bedrock/data/DSR/GLASS/rawdata
# OUT_DIR: /share/home/dq076/bedrock/data/DSR/GLASS/8D
# Range  : 2003-01-01 -> 2020-12-31 (8-day non-overlap)
# AGG    : timmean
# Output dtype: Float32
# Target SRS: EPSG:4326
# Note: Data already in geographic coordinates, using -a_srs (not reprojection)
# [RUN ] A2003001: 2003-01-01 .. 2003-01-08
#     Converting GLASS05B01.V42.A2003001.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003002.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003003.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003004.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003005.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003006.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003007.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003008.2020313.hdf to netCDF...
# [OK ] A2003001 -> DSR_GLASS_2003001_8D_p05_Wm2.nc4
# [RUN ] A2003009: 2003-01-09 .. 2003-01-16
#     Converting GLASS05B01.V42.A2003009.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003010.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003011.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003012.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003013.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003014.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003015.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003016.2020313.hdf to netCDF...
# [OK ] A2003009 -> DSR_GLASS_2003009_8D_p05_Wm2.nc4
# [RUN ] A2003017: 2003-01-17 .. 2003-01-24
#     Converting GLASS05B01.V42.A2003017.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003018.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003019.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003020.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003021.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003022.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003023.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003024.2020313.hdf to netCDF...
# [OK ] A2003017 -> DSR_GLASS_2003017_8D_p05_Wm2.nc4
# [RUN ] A2003025: 2003-01-25 .. 2003-02-01
#     Converting GLASS05B01.V42.A2003025.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003026.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003027.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003028.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003029.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003030.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003031.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2003032.2020313.hdf to netCDF...
# [OK ] A2003025 -> DSR_GLASS_2003025_8D_p05_Wm2.nc4
# [RUN ] A2003033: 2003-02-02 .. 2003-02-09
#     Converting GLASS05B01.V42.A2003033.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2
2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005101.2020313.hdf to netCDF...
# [OK ] A2005094 -> DSR_GLASS_2005094_8D_p05_Wm2.nc4
# [RUN ] A2005102: 2005-04-12 .. 2005-04-19
#     Converting GLASS05B01.V42.A2005102.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005103.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005104.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005105.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005106.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005107.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005108.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005109.2020313.hdf to netCDF...
# [OK ] A2005102 -> DSR_GLASS_2005102_8D_p05_Wm2.nc4
# [RUN ] A2005110: 2005-04-20 .. 2005-04-27
#     Converting GLASS05B01.V42.A2005110.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005111.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005112.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005113.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005114.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005115.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005116.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005117.2020313.hdf to netCDF...
# [OK ] A2005110 -> DSR_GLASS_2005110_8D_p05_Wm2.nc4
# [RUN ] A2005118: 2005-04-28 .. 2005-05-05
#     Converting GLASS05B01.V42.A2005118.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005119.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005120.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005121.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005122.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005123.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005124.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005125.2020313.hdf to netCDF...
# [OK ] A2005118 -> DSR_GLASS_2005118_8D_p05_Wm2.nc4
# [RUN ] A2005126: 2005-05-06 .. 2005-05-13
#     Converting GLASS05B01.V42.A2005126.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005127.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005128.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005129.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005130.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005131.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005132.2020313.hdf to netCDF...
#     Converting GLASS05B01.V42.A2005133.2020313.hdf to netCDF...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 229
#     227 if __name__ == "__main__":
#     228     try:
# --> 229         main()
#     230     except Exception as e:
#     231         print(f"[FATAL] {e}", file=sys.stderr)
#
# Cell In[5], line 216, in main()
#     213         export_daily_nc(d, hdf, day_nc)
#     214         daily_ncs.append(day_nc)
# --> 216     make_8day(daily_ncs, out_nc)
#     218 print(f"[OK ] A{key} -> {out_nc.name}")
#     219 n_done += 1
#
# Cell In[5], line 147, in make_8day(daily_files, out_nc)
#     144 merged = td / "merged.nc4"
#     146 # 合并时间序列
# --> 147 run([
#     148     "cdo", "-O", "-L",
#     149     "-f", "nc4", "-z", "zip_3",
#     150     "mergetime", *map(str, daily_files), str(merged)
#     151 ])
#     153 # 计算8天聚合
#     154 run([
#     155     "cdo", "-O", "-L",
#     156     "-f", "nc4", "-z", "zip_3",
#     157     AGG, str(merged), str(out_nc)
#     158 ])
#
# Cell In[5], line 51, in run(cmd, cwd)
#      50 def run(cmd, cwd=None):
# ---> 51     p = subprocess.run(cmd, cwd=cwd, text=True, capture_output=True)
#      52     if p.returncode != 0:
#      53         raise RuntimeError(
#      54             "Command failed:\n"
#      55             f"  cmd: {' '.join(cmd)}\n"
#    (...)
#      58             f"  stderr:\n{p.stderr}\n"
#      59         )
#
# File ~/software/miniconda3/envs/gdal/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~/software/miniconda3/envs/gdal/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File ~/software/miniconda3/envs/gdal/lib/python3.10/subprocess.py:2021, in Popen._communicate(self, input, endtime, orig_timeout)
#    2014     self._check_timeout(endtime, orig_timeout,
#    2015                         stdout, stderr,
#    2016                         skip_check_and_raise=True)
#    2017     raise RuntimeError(  # Impossible :)
#    2018         '_check_timeout(..., skip_check_and_raise=True) '
#    2019         'failed to raise TimeoutExpired.')
# -> 2021 ready = selector.select(timeout)
#    2022 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2024 # XXX Rewrite these to use non-blocking I/O on the file
#    2025 # objects; they are no longer using C stdio!
#
# File ~/software/miniconda3/envs/gdal/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:
